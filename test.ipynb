# %%
import pandas
import numpy 
from matplotlib import pyplot as plt

# %%
ucb = pandas.read_csv("ucb.csv",header=None )
mab = pandas.read_csv("mab.csv",header=None )
fuzzy = pandas.read_csv("fuzzy.csv", header=None )
DQN = pandas.read_csv("DQN.csv", header=None )
FDQO = pandas.read_csv("FDQO.csv", header = None )

# %%
ucb
# Out:
#                0
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# ...          ...
# 143030  0.805409
# 143031  0.805407
# 143032  0.805402
# 143033  0.805397
# 143034  0.805394
#
# [143035 rows x 1 columns]

# %%
df = pandas.DataFrame(ucb)
df["mab"] = mab
df["fuzzy"] = fuzzy
df["DQN"] = DQN
df["FDQO"] = FDQO
df
# Out:
#                0       mab     fuzzy       DQN      FDQO
# 0       1.000000  1.000000  1.000000  1.000000  1.000000
# 1       1.000000  1.000000  1.000000  1.000000  1.000000
# 2       1.000000  1.000000  1.000000  1.000000  1.000000
# 3       1.000000  1.000000  1.000000  1.000000  1.000000
# 4       1.000000  1.000000  1.000000  1.000000  1.000000
# ...          ...       ...       ...       ...       ...
# 143030  0.805409  0.803257  0.825266  0.895459  0.825266
# 143031  0.805407  0.803255  0.825261  0.895453  0.825261
# 143032  0.805402  0.803252  0.825256  0.895452  0.825256
# 143033  0.805397  0.803247  0.825254  0.895449  0.825254
# 143034  0.805394  0.803246  0.825251  0.895445  0.825251
#
# [143035 rows x 5 columns]

# %%
Frame=pandas.DataFrame(df.values, columns = ["ucb", "mab", "fuzzy", "DQN","FDQO"])

# %%
Frame.plot.line()
plt.show()
